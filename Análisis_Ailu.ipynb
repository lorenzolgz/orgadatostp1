# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("/home/ailen-magali/train.csv")

# %%
df.head().T
# Out:
#                                                                             0  \
# id                                                                     254099
# titulo                                                      depto. tipo a-402
# descripcion                 depto. interior de 80.15m2, consta de sala com...
# tipodepropiedad                                                   Apartamento
# direccion                                     Avenida Division del Norte 2005
# ciudad                                                          Benito Juárez
# provincia                                                    Distrito Federal
# antiguedad                                                                NaN
# habitaciones                                                                2
# garages                                                                     1
# banos                                                                       2
# metroscubiertos                                                            80
# metrostotales                                                              80
# idzona                                                                  23533
# lat                                                                       NaN
# lng                                                                       NaN
# fecha                                                     2015-08-23 00:00:00
# gimnasio                                                                    0
# usosmultiples                                                               0
# piscina                                                                     0
# escuelascercanas                                                            0
# centroscomercialescercanos                                                  0
# precio                                                              2.273e+06
#
#                                                                             1  \
# id                                                                      53461
# titulo                                         condominio horizontal en venta
# descripcion                 <p>entre sonora y guerrero, atr&aacute;s del h...
# tipodepropiedad                                            Casa en condominio
# direccion                                                          AV. MEXICO
# ciudad                                                 La Magdalena Contreras
# provincia                                                    Distrito Federal
# antiguedad                                                                 10
# habitaciones                                                                3
# garages                                                                     2
# banos                                                                       2
# metroscubiertos                                                           268
# metrostotales                                                             180
# idzona                                                                  24514
# lat                                                                   19.3102
# lng                                                                  -99.2277
# fecha                                                     2013-06-28 00:00:00
# gimnasio                                                                    0
# usosmultiples                                                               0
# piscina                                                                     0
# escuelascercanas                                                            1
# centroscomercialescercanos                                                  1
# precio                                                                3.6e+06
#
#                                                                             2  \
# id                                                                     247984
# titulo                                  casa en venta urbi 3 recamaras tonala
# descripcion                 descripcion \nla mejor ubicacion residencial e...
# tipodepropiedad                                                          Casa
# direccion                                                         Urbi Tonala
# ciudad                                                                 Tonalá
# provincia                                                             Jalisco
# antiguedad                                                                  5
# habitaciones                                                                3
# garages                                                                     2
# banos                                                                       2
# metroscubiertos                                                           144
# metrostotales                                                             166
# idzona                                                                  48551
# lat                                                                       NaN
# lng                                                                       NaN
# fecha                                                     2015-10-17 00:00:00
# gimnasio                                                                    0
# usosmultiples                                                               0
# piscina                                                                     0
# escuelascercanas                                                            0
# centroscomercialescercanos                                                  0
# precio                                                                1.2e+06
#
#                                                                             3  \
# id                                                                     209067
# titulo                      casa sola en toluca zinacantepec con credito i...
# descripcion                 casa en privada con caseta de vigilancia casas...
# tipodepropiedad                                                          Casa
# direccion                                       IGNACIO MANUEL ALTAMIRANO 128
# ciudad                                                           Zinacantepec
# provincia                                                      Edo. de México
# antiguedad                                                                  1
# habitaciones                                                                2
# garages                                                                     1
# banos                                                                       1
# metroscubiertos                                                            63
# metrostotales                                                              67
# idzona                                                                  53666
# lat                                                                   19.3019
# lng                                                                   -99.688
# fecha                                                     2012-03-09 00:00:00
# gimnasio                                                                    0
# usosmultiples                                                               0
# piscina                                                                     0
# escuelascercanas                                                            1
# centroscomercialescercanos                                                  1
# precio                                                                 650000
#
#                                                                             4
# id                                                                     185997
# titulo                                                         paseos del sol
# descripcion                 bonito departamento en excelentes condiciones ...
# tipodepropiedad                                                   Apartamento
# direccion                                                     PASEOS DEL SOL
# ciudad                                                                Zapopan
# provincia                                                             Jalisco
# antiguedad                                                                 10
# habitaciones                                                                2
# garages                                                                     1
# banos                                                                       1
# metroscubiertos                                                            95
# metrostotales                                                              95
# idzona                                                                  47835
# lat                                                                       NaN
# lng                                                                       NaN
# fecha                                                     2016-06-07 00:00:00
# gimnasio                                                                    0
# usosmultiples                                                               0
# piscina                                                                     0
# escuelascercanas                                                            0
# centroscomercialescercanos                                                  0
# precio                                                               1.15e+06

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 240000 entries, 0 to 239999
# Data columns (total 23 columns):
# id                            240000 non-null int64
# titulo                        234613 non-null object
# descripcion                   238381 non-null object
# tipodepropiedad               239954 non-null object
# direccion                     186928 non-null object
# ciudad                        239628 non-null object
# provincia                     239845 non-null object
# antiguedad                    196445 non-null float64
# habitaciones                  217529 non-null float64
# garages                       202235 non-null float64
# banos                         213779 non-null float64
# metroscubiertos               222600 non-null float64
# metrostotales                 188533 non-null float64
# idzona                        211379 non-null float64
# lat                           116512 non-null float64
# lng                           116512 non-null float64
# fecha                         240000 non-null object
# gimnasio                      240000 non-null float64
# usosmultiples                 240000 non-null float64
# piscina                       240000 non-null float64
# escuelascercanas              240000 non-null float64
# centroscomercialescercanos    240000 non-null float64
# precio                        240000 non-null float64
# dtypes: float64(15), int64(1), object(7)
# memory usage: 42.1+ MB

# %%
df['escuelascercanas'].value_counts()
# Out:
# 0.0    133406
# 1.0    106594
# Name: escuelascercanas, dtype: int64

# %%
df['piscina'].value_counts()
# Out:
# 0.0    219028
# 1.0     20972
# Name: piscina, dtype: int64

# %%
df['centroscomercialescercanos'].value_counts()
# Out:
# 0.0    144832
# 1.0     95168
# Name: centroscomercialescercanos, dtype: int64

# %%
df['gimnasio'].value_counts()
# Out:
# 0.0    225006
# 1.0     14994
# Name: gimnasio, dtype: int64

# %%
df['usosmultiples'].value_counts()
# Out:
# 0.0    226778
# 1.0     13222
# Name: usosmultiples, dtype: int64

# %%
df['precio'].value_counts()
# Out:
# 1500000.0     3041
# 2500000.0     3036
# 1200000.0     2909
# 3500000.0     2726
# 1300000.0     2480
# 2200000.0     2420
# 1100000.0     2394
# 1800000.0     2290
# 1600000.0     2217
# 850000.0      2192
# 750000.0      2163
# 1250000.0     2159
# 2300000.0     2108
# 1350000.0     2103
# 650000.0      2061
# 3200000.0     2054
# 4500000.0     2040
# 2000000.0     1904
# 950000.0      1867
# 1650000.0     1865
# 2800000.0     1863
# 1400000.0     1850
# 550000.0      1820
# 2100000.0     1802
# 3000000.0     1791
# 1700000.0     1763
# 1850000.0     1760
# 2600000.0     1735
# 1150000.0     1722
# 1750000.0     1702
#               ...
# 10807000.0       1
# 468778.0         1
# 675411.0         1
# 468768.0         1
# 7500250.0        1
# 10815000.0       1
# 3752490.0        1
# 469105.0         1
# 338144.0         1
# 1352990.0        1
# 938630.0         1
# 10822700.0       1
# 2705670.0        1
# 1877000.0        1
# 407500.0         1
# 1352610.0        1
# 676300.0         1
# 2705184.0        1
# 938426.0         1
# 1876500.0        1
# 1352560.0        1
# 469208.0         1
# 1352520.0        1
# 469200.0         1
# 5410000.0        1
# 2704600.0        1
# 1352250.0        1
# 938260.0         1
# 2704460.0        1
# 2327000.0        1
# Name: precio, Length: 15520, dtype: int64

# %%
#NUMERICOS ENTEROS QUE ERAN INNECESARIAMENTE FLOAT
#------------------------------------------------#

#NUMERICOS QUE SOLO SON CERO O UNO
df['usosmultiples'] = df['usosmultiples'].astype(np.int8)
df['piscina'] = df['piscina'].astype(np.int8)
df['gimnasio'] = df['gimnasio'].astype(np.int8)
df['escuelascercanas'] = df['escuelascercanas'].astype(np.int8)
df['centroscomercialescercanos'] = df['centroscomercialescercanos'].astype(np.int8)


#FECHA DE PUBLICACION A DATETIME
df['fecha'] = pd.to_datetime(df['fecha'])


# A estos hay que limpiarles los inf y los NaN antes de convertir a int

#df['antiguedad'] = df.antiguedad.astype('int64')
#df['garages'] = df.garages.astype('int64')
#df['habitaciones'] = df.habitaciones.astype('int64')
#df['metrostotales'] = df.metrostotales.astype('int64')
#df['metroscubiertos'] = df.metroscubiertos.astype('int64')
#df['idzona'] = df.idzona.astype('int64')

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 240000 entries, 0 to 239999
# Data columns (total 23 columns):
# id                            240000 non-null int64
# titulo                        234613 non-null object
# descripcion                   238381 non-null object
# tipodepropiedad               239954 non-null object
# direccion                     186928 non-null object
# ciudad                        239628 non-null object
# provincia                     239845 non-null object
# antiguedad                    196445 non-null float64
# habitaciones                  217529 non-null float64
# garages                       202235 non-null float64
# banos                         213779 non-null float64
# metroscubiertos               222600 non-null float64
# metrostotales                 188533 non-null float64
# idzona                        211379 non-null float64
# lat                           116512 non-null float64
# lng                           116512 non-null float64
# fecha                         240000 non-null datetime64[ns]
# gimnasio                      240000 non-null int8
# usosmultiples                 240000 non-null int8
# piscina                       240000 non-null int8
# escuelascercanas              240000 non-null int8
# centroscomercialescercanos    240000 non-null int8
# precio                        240000 non-null float64
# dtypes: datetime64[ns](1), float64(10), int64(1), int8(5), object(6)
# memory usage: 34.1+ MB

# %%
# A estos hay que limpiarles los inf y los NaN antes de convertir a int

#df['antiguedad'] = df.antiguedad.astype('int64')
#df['garages'] = df.garages.astype('int64')
#df['habitaciones'] = df.habitaciones.astype('int64')
#df['metrostotales'] = df.metrostotales.astype('int64')
#df['metroscubiertos'] = df.metroscubiertos.astype('int64')
#df['idzona'] = df.idzona.astype('int64')

# %%
df['antiguedad'].value_counts()
# Out:
# 0.0     50335
# 5.0     33268
# 10.0    28844
# 20.0    19904
# 1.0     12353
# 4.0      7944
# 3.0      5616
# 2.0      5059
# 15.0     3965
# 6.0      3169
# 30.0     3055
# 8.0      2418
# 25.0     2297
# 7.0      2046
# 12.0     1492
# 11.0     1434
# 40.0     1347
# 50.0     1193
# 9.0      1065
# 35.0      938
# 18.0      908
# 21.0      742
# 16.0      700
# 14.0      616
# 13.0      577
# 17.0      529
# 22.0      448
# 28.0      396
# 26.0      369
# 45.0      329
#         ...
# 47.0       40
# 55.0       38
# 48.0       36
# 46.0       31
# 70.0       29
# 41.0       27
# 80.0       27
# 53.0       17
# 49.0       17
# 65.0       17
# 52.0       11
# 58.0       10
# 54.0        9
# 75.0        6
# 66.0        5
# 59.0        5
# 69.0        5
# 67.0        4
# 57.0        4
# 63.0        4
# 62.0        3
# 56.0        3
# 74.0        2
# 68.0        2
# 79.0        2
# 61.0        2
# 76.0        2
# 71.0        1
# 77.0        1
# 64.0        1
# Name: antiguedad, Length: 78, dtype: int64

# %%
len(df)
# Out:
# 240000

# %%
#Vemos cuántos NaN hay por columna, sabiendo que el total es 240000
df.isnull().sum()
# Out:
# id                                 0
# titulo                          5387
# descripcion                     1619
# tipodepropiedad                   46
# direccion                      53072
# ciudad                           372
# provincia                        155
# antiguedad                     43555
# habitaciones                   22471
# garages                        37765
# banos                          26221
# metroscubiertos                17400
# metrostotales                  51467
# idzona                         28621
# lat                           123488
# lng                           123488
# fecha                              0
# gimnasio                           0
# usosmultiples                      0
# piscina                            0
# escuelascercanas                   0
# centroscomercialescercanos         0
# precio                             0
# dtype: int64

# %%
#Reemplazo los NaN por 0
df.loc[(df['lat']).isnull(),['lat']]=0
df.loc[(df['lng']).isnull(),['lng']]=0

# %%
df['lat'].isnull().sum()
# Out:
# 0

# %%
df['lng'].isnull().sum()
# Out:
# 0

# %%
df['lat'].value_counts()
# Out:
# 0.000000     123936
# 23.063781         8
# 23.054936         7
# 19.314000         6
# 19.392000         6
# 19.391000         6
# 19.617000         6
# 19.393000         6
# 19.358000         6
# 19.489000         6
# 23.053672         6
# 19.558000         6
# 19.457000         6
# 19.410000         6
# 32.454473         5
# 23.068835         5
# 19.300000         5
# 19.332000         5
# 19.503000         5
# 19.369000         5
# 19.485000         5
# 19.388000         5
# 19.344000         5
# 19.350000         5
# 19.387000         5
# 19.437000         5
# 19.397000         5
# 19.478000         5
# 19.444000         5
# 19.494000         5
#               ...
# 17.094446         1
# 20.997915         1
# 19.591669         1
# 19.417518         1
# 19.727337         1
# 19.476194         1
# 19.359454         1
# 19.287115         1
# 18.987497         1
# 19.495689         1
# 20.662757         1
# 19.492759         1
# 20.743466         1
# 21.160287         1
# 19.433077         1
# 19.359921         1
# 19.361805         1
# 20.642669         1
# 24.009796         1
# 32.485229         1
# 32.445024         1
# 20.658414         1
# 23.284804         1
# 22.645698         1
# 21.025559         1
# 25.675224         1
# 18.151347         1
# 18.779346         1
# 21.963000         1
# 19.505390         1
# Name: lat, Length: 112147, dtype: int64

# %%
df['lng'].value_counts()
# Out:
#  0.000000      123937
# -99.225000         12
# -99.218984          9
# -99.139000          8
# -99.213000          8
# -99.230000          8
# -99.143540          7
# -99.156000          7
# -99.125000          7
# -99.191000          7
# -99.227000          7
# -99.177446          7
# -99.234000          7
# -99.200000          7
# -99.144000          7
# -99.183676          7
# -99.163000          7
# -99.175000          6
# -99.171909          6
# -99.055727          6
# -99.153000          6
# -99.195000          6
# -99.202366          6
# -99.133163          6
# -99.170000          6
# -99.258000          6
# -99.226000          6
# -99.165000          6
# -99.211000          6
# -99.161000          6
#                 ...
# -100.976336         1
# -103.439241         1
# -103.464754         1
# -96.191890          1
# -99.303276          1
# -116.761322         1
# -106.117890         1
# -99.007759          1
# -98.941038          1
# -100.369562         1
# -102.311859         1
# -99.156190          1
# -99.136433          1
# -100.102952         1
# -100.428454         1
# -103.461922         1
# -99.285294          1
# -100.240945         1
# -98.213833          1
# -99.191613          1
# -99.185678          1
# -101.557630         1
# -103.387854         1
# -100.316000         1
# -102.308277         1
# -103.449196         1
# -100.443135         1
# -106.103384         1
# -99.168257          1
# -99.131383          1
# Name: lng, Length: 112326, dtype: int64

# %%
#Ahora cambio el tipo de dato de las columnas 'lat' y 'lng'
df['lat'] = df['lat'].astype(np.float32)
df['lng'] = df['lng'].astype(np.float32)

# %%
df['titulo'].value_counts()
# Out:
# casa en venta                                                                       468
# departamento en venta                                                               289
# casa en venta en chihuahua                                                          268
# casa en venta en querétaro                                                          238
# departamento en venta en benito juárez                                              221
# departamento en venta en miguel hidalgo                                             177
# casa en venta en mérida                                                             167
# casa en venta                                                                       132
# casa en venta en torreón                                                            119
# casa en venta en monterrey                                                          115
# casa en venta en mérida, yucatán                                                    115
# casa en venta en puebla                                                             112
# casa en venta en juárez                                                             111
# casa en venta en tepic                                                              107
# casa en venta en juriquilla                                                         106
# casa en venta en san andrés cholula                                                 105
# casa en venta en tijuana                                                            104
# venta de casa en aguascalientes                                                      98
# terreno en venta                                                                     97
# departamento                                                                         89
# casa en condominio en venta en querétaro                                             86
# departamento en venta en cuauhtémoc                                                  84
# venta de departamento en benito juárez                                               84
# venta de casa en naucalpan                                                           84
# casa en venta en corregidora                                                         83
# casa en venta en zapopan                                                             80
# departamento en venta en interlomas                                                  80
# casa en venta, monterrey, nuevo león                                                 80
# venta de casa en cuautitlan izcalli                                                  79
# venta de casa en tlalnepantla                                                        78
#                                                                                    ...
# excelente oportunidad de remate bancario, casa en condominio en cuernavaca!!!         1
# vendo casa en conjunto en la noria  rec                                               1
# milenio iii se vende linda casa nueva minimalista con recamara p.b.                   1
# casa venta albaterra ii,                                                              1
# casa sola en muy buena ubicacion                                                      1
# departamento en san ciprian del v. carranza.                                          1
# yalta campestre, cerrada, cerca del tec. de mty. y de softtek, urge cambio de cd      1
# casas en venta rancho san pedro                                                       1
# casas nuevas en lázaro cárdenas, michoacan.                                           1
# casa sola en venta. vergel coyoacan                                                   1
# terreno / lote en venta en nextengo                                                   1
# local comercial en venta en interlomas                                                1
# venta departamento en el sur de la ciudad                                             1
# excelente oportunidad bonita casa en privada de 8 casas a 2 min de tollocan           1
# amplia casa en col. industrias del vidrio ampliación oriente excelente ubicación      1
# venta de departamentos ubicados en la calle de rio panuco, colonia cuauhtemoc.        1
# casa en zona sur, pedregal la silla.                                                  1
# campo real                                                                            1
# hermosas casas en privada cerrada a 1 minuto del periférico                           1
# jardines de pensiones                                                                 1
# interlomas, hacienda del ciervo                                                       1
# modelo cuarzo                                                                         1
# casa en venta en pueblo santa lucia del camino                                        1
# remato casa burgos cuernavaca, 4 recamaras y alberca.                                 1
# casa residencial en venta en manantiales de  cocoyoles                                1
# vendo hermosa casa en toluca                                                          1
# aprovecha hoy! se vende la  de tus sueños en barcelona residencial                    1
# 101                                                                                   1
# se vende linda casa en san cristobal                                                  1
# en la zona romantica de puerto vallarta, departamento totalmente amueblado            1
# Name: titulo, Length: 186191, dtype: int64

# %%
#Elimino los NaN
df.loc[(df['titulo']).isnull(), ['titulo']] = ''
df['titulo'] = df['titulo'].astype(str)

# %%
df['banos'].value_counts()
# Out:
# 2.0    87683
# 1.0    58173
# 3.0    49365
# 4.0    18558
# Name: banos, dtype: int64

# %%
#Lo paso a tipo category porque tenemos 4 valores distintos 
df.loc[(df['banos']).isnull(), ['banos']] = 0
df['banos'] = df['banos'].astype('category')

# %%
df['garages'].value_counts()
# Out:
# 2.0    94167
# 1.0    59464
# 0.0    26926
# 3.0    21678
# Name: garages, dtype: int64

# %%
#Lo paso a tipo category porque tenemos 4 valores distintos 
df.loc[(df['garages']).isnull(), ['garages']] = 0
df['garages'] = df['garages'].astype('category')

# %%
df['direccion'].value_counts()
# Out:
# -                                                                      660
# .                                                                      476
# 1                                                                      212
# Calle                                                                  194
# Norte de Mérida                                                        136
# x #x                                                                   122
# 0                                                                      113
# domicilio conocido                                                     105
# Calle 18 No.344 x 11 y 13 Col. Camara de Comercio Norte                 94
# calle                                                                   94
# Juriquilla                                                              84
# El Refugio                                                              78
# x                                                                       77
# Metepec                                                                 77
# CENTRO                                                                  75
# JURIQUILLA                                                              74
# ...                                                                     70
# Sin nombre                                                              70
# Bosque Real                                                             68
# EL REFUGIO                                                              68
# Chihuahua, CHIH, México                                                 67
# CALLE                                                                   66
# S/N                                                                     65
# Norte                                                                   64
# Cumbres del Lago                                                        64
# --                                                                      64
# Centro                                                                  62
# S/D                                                                     62
# cancun                                                                  58
# Emiliano Zapata                                                         55
#                                                                       ...
# paseo de granada 200 esquina virrey de mendoza                           1
# Morelos 122                                                              1
# villa sur                                                                1
# CUAUHTEMOC 63                                                            1
# Darío Peralta, Casa No 465, Lt. 189 Y 190, Mz I, Uh Tamsa Infonavit      1
# Presas 33                                                                1
# Montaña de Omoa                                                          1
# Avenida Azcapotzalco 440                                                 1
# Cto. Las Águilas No. 91. Col Jardines de las Animas                      1
# CERRADA DE LERDO                                                         1
# AVE. PENINSULA 2629                                                      1
# Vista Escorial # 208                                                     1
# COLEADERO 22                                                             1
# GUADALUPE VICTORIA 516                                                   1
# PENSADOR                                                                 1
# Colonia del Valle Sur                                                    1
# Leona Vicario y Obregón                                                  1
# Calle justicia esq Beliario Dominguez                                    1
# SANTIAGO DE LA PEÑA                                                      1
# Rep. de Cuba                                                             1
# Tetelpan                                                                 1
# Ex Hacienda del Rosario                                                  1
# Paseo de los Ficus                                                       1
# REMANSO, Jardines del Pedregal de San Angel, Coyoacán                    1
# Privada Prolongacion 3 Norte 5                                           1
# OKLAHOMA 23                                                              1
# Cantaros de Salitrillo                                                   1
# noche buenas                                                             1
# Guayacahuala IMS-563-Ca                                                  1
# HACIENDA DE LAS PALMAS SUR 258                                           1
# Name: direccion, Length: 140269, dtype: int64

# %%
#Limpio las direcciones que no son calles

df.loc[(df['direccion']).isnull(), ['direccion']] = 'S/D'
df.loc[(df['direccion']) == 'S/N', ['direccion']] = 'S/D'
df.loc[(df['direccion']) == 'Sin nombre', ['direccion']] = 'S/D'
df.loc[(df['direccion']) == '0', ['direccion']] = 'S/D'
df.loc[(df['direccion']) == '--', ['direccion']] = 'S/D'
df.loc[(df['direccion']) == '...', ['direccion']] = 'S/D'
df.loc[(df['direccion']) == '-', ['direccion']] = 'S/D'
df.loc[(df['direccion']) == '.', ['direccion']] = 'S/D'
df.loc[(df['direccion']) == 'x #x', ['direccion']] = 'S/D'
df.loc[(df['direccion']) == 'x', ['direccion']] = 'S/D'
df.loc[(df['direccion']) == 'calle', ['direccion']] = 'S/D'
df.loc[(df['direccion']) == 'Calle', ['direccion']] = 'S/D'
df.loc[(df['direccion']) == '1', ['direccion']] = 'S/D'
df.loc[(df['direccion']) == 'X', ['direccion']] = 'S/D'

# %%
df['direccion'] = df['direccion'].astype('str')

# %% [markdown]
# Servicios vs precio

# %%
df['tipodepropiedad'].value_counts()
# Out:
# Casa                             141717
# Apartamento                       57341
# Casa en condominio                19297
# Terreno                            9945
# Local Comercial                    3055
# Oficina comercial                  1741
# Bodega comercial                   1406
# Edificio                           1396
# Terreno comercial                  1326
# Casa uso de suelo                   708
# Quinta Vacacional                   395
# Duplex                              343
# Villa                               340
# Inmuebles productivos urbanos       200
# Rancho                              170
# Local en centro comercial           165
# Departamento Compartido             141
# Otros                               134
# Nave industrial                      76
# Terreno industrial                   31
# Huerta                               20
# Lote                                  5
# Garage                                1
# Hospedaje                             1
# Name: tipodepropiedad, dtype: int64

# %%
df['categoria_servicio'] = df['gimnasio'] + df['usosmultiples'] + df['piscina'] + df['escuelascercanas'] + df['centroscomercialescercanos']

# %%
serviciovsprecio_df1 = df.loc[( (df['tipodepropiedad'] == 'Casa') | (df['tipodepropiedad'] == 'Apartamento') | \
              (df['tipodepropiedad'] == 'Casa en condominio') | (df['tipodepropiedad'] == 'Edificio') | \
              (df['tipodepropiedad'] == 'Quinta Vacacional') | (df['tipodepropiedad'] == 'Duplex') | \
              (df['tipodepropiedad'] == 'Rancho') | (df['tipodepropiedad'] == 'Departamento Compartido') | \
              (df['tipodepropiedad'] == 'Hospedaje') )]

# %%
serviciovsprecio_df1['tipodepropiedad'].value_counts()
# Out:
# Casa                       141717
# Apartamento                 57341
# Casa en condominio          19297
# Edificio                     1396
# Quinta Vacacional             395
# Duplex                        343
# Rancho                        170
# Departamento Compartido       141
# Hospedaje                       1
# Name: tipodepropiedad, dtype: int64

# %%
serviciovsprecio_df2 = serviciovsprecio_df1[['categoria_servicio', 'precio']]
serviciovsprecio_df = serviciovsprecio_df2.groupby('categoria_servicio')['precio'].agg('mean').reset_index()
serviciovsprecio_df['categoria_servicio'] = serviciovsprecio_df['categoria_servicio'].astype(np.int8)
serviciovsprecio_df
# Out:
#    categoria_servicio        precio
# 0                   0  2.497758e+06
# 1                   1  2.427747e+06
# 2                   2  2.377389e+06
# 3                   3  3.150838e+06
# 4                   4  3.737360e+06
# 5                   5  4.491902e+06

# %%
serviciovsprecio_df.max()
# Out:
# categoria_servicio    5.000000e+00
# precio                4.491902e+06
# dtype: float64

# %%
serviciovsprecio_df.min()
# Out:
# categoria_servicio    0.000000e+00
# precio                2.377389e+06
# dtype: float64

# %%
fig, ax1 = plt.subplots() # prepara un gráfico de matplotlib
serviciovsprecio_df.plot("precio", "categoria_servicio", kind="scatter", ax=ax1, figsize=(10,10), color='purple')

# realiza ajustes al gráfico con matplotlib:
ax1.grid()
ax1.set_xlabel("Precio", fontsize=15)
ax1.set_ylabel("Categoría del servicio", fontsize=15)
ax1.tick_params(labelsize=10, pad=10)
fig.suptitle('Precio de las propiedades según la categoría de los servicios', fontsize=20)

plt.savefig('/home/ailen-magali/Documentos/precio_por_categorias.png', bbox_inches = 'tight', pad_inches = 0.1)

# %% [markdown]
# Precio dependiendo de la latitud y la longitud

# %%
df1 = df[['lng', 'lat', 'precio']]
df2 = df1.loc[(df1['lng'] != 0) & (df1['lat'] != 0)]

df3 = df2.loc[(df2['lat'] < 50) & (df2['lat'] > 13)
                                &(df2['lng'] < -80) & (df2['lng'] > -120)]

x = df3['lng']*10000
y = df3['lat']*10000
size = df3['precio']/10000
colors = df3['precio']

# %%
plt.figure(figsize=(25,15))
plt.ylabel('Latitud', fontsize=15)
plt.xlabel('Longitud', fontsize=15)
plt.scatter(x, y, s=size, c=colors, cmap='coolwarm')
plt.colorbar()

plt.title('Precio por coordenadas', fontsize=20)

plt.savefig('/home/ailen-magali/Documentos/precio_por_coordenadas.png', bbox_inches = 'tight', pad_inches = 0.1)

plt.show()
plt.clf()

# %%
df['año'] = pd.DatetimeIndex(df['fecha']).year.astype(np.int16)
df_anio_precio = df[['año', 'precio']]

# %% [markdown]
# Precio por fecha de publicación

# %%
plt.figure(figsize=(10,10))
g = sns.boxplot(x="año", y="precio", data=df_anio_precio, palette="husl", fliersize=1)
g.set_title("Precio de las propiedades según año de publicación", fontsize=25)
g.set_ylabel("Precio", fontsize=20)
g.set_xlabel("Año publicación", fontsize=20)

plt.savefig('/home/ailen-magali/Documentos/precio_por_año.png', bbox_inches = 'tight', pad_inches = 0.1)
