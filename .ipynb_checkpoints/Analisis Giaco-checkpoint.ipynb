# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

plt.style.use('default') # haciendo los graficos un poco mas bonitos en matplotlib

sns.set(style="whitegrid") # seteando tipo de grid en seaborn

df = pd.read_csv("train.csv")

# %%
print(len(df))
df.head()
# Out:
# 240000
#        id                                             titulo  \
# 0  254099                                  depto. tipo a-402
# 1   53461                     condominio horizontal en venta
# 2  247984              casa en venta urbi 3 recamaras tonala
# 3  209067  casa sola en toluca zinacantepec con credito i...
# 4  185997                                     paseos del sol
#
#                                          descripcion     tipodepropiedad  \
# 0  depto. interior de 80.15m2, consta de sala com...         Apartamento
# 1  <p>entre sonora y guerrero, atr&aacute;s del h...  Casa en condominio
# 2  descripcion \nla mejor ubicacion residencial e...                Casa
# 3  casa en privada con caseta de vigilancia casas...                Casa
# 4  bonito departamento en excelentes condiciones ...         Apartamento
#
#                          direccion                  ciudad         provincia  \
# 0  Avenida Division del Norte 2005           Benito Juárez  Distrito Federal
# 1                       AV. MEXICO  La Magdalena Contreras  Distrito Federal
# 2                      Urbi Tonala                  Tonalá           Jalisco
# 3    IGNACIO MANUEL ALTAMIRANO 128            Zinacantepec    Edo. de México
# 4                  PASEOS DEL SOL                  Zapopan           Jalisco
#
#    antiguedad  habitaciones  garages  ...   idzona        lat        lng  \
# 0         NaN           2.0      1.0  ...  23533.0        NaN        NaN
# 1        10.0           3.0      2.0  ...  24514.0  19.310205 -99.227655
# 2         5.0           3.0      2.0  ...  48551.0        NaN        NaN
# 3         1.0           2.0      1.0  ...  53666.0  19.301890 -99.688015
# 4        10.0           2.0      1.0  ...  47835.0        NaN        NaN
#
#                  fecha  gimnasio  usosmultiples piscina  escuelascercanas  \
# 0  2015-08-23 00:00:00       0.0            0.0     0.0               0.0
# 1  2013-06-28 00:00:00       0.0            0.0     0.0               1.0
# 2  2015-10-17 00:00:00       0.0            0.0     0.0               0.0
# 3  2012-03-09 00:00:00       0.0            0.0     0.0               1.0
# 4  2016-06-07 00:00:00       0.0            0.0     0.0               0.0
#
#    centroscomercialescercanos     precio
# 0                         0.0  2273000.0
# 1                         1.0  3600000.0
# 2                         0.0  1200000.0
# 3                         1.0   650000.0
# 4                         0.0  1150000.0
#
# [5 rows x 23 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 240000 entries, 0 to 239999
# Data columns (total 23 columns):
# id                            240000 non-null int64
# titulo                        234613 non-null object
# descripcion                   238381 non-null object
# tipodepropiedad               239954 non-null object
# direccion                     186928 non-null object
# ciudad                        239628 non-null object
# provincia                     239845 non-null object
# antiguedad                    196445 non-null float64
# habitaciones                  217529 non-null float64
# garages                       202235 non-null float64
# banos                         213779 non-null float64
# metroscubiertos               222600 non-null float64
# metrostotales                 188533 non-null float64
# idzona                        211379 non-null float64
# lat                           116512 non-null float64
# lng                           116512 non-null float64
# fecha                         240000 non-null datetime64[ns]
# gimnasio                      240000 non-null bool
# usosmultiples                 240000 non-null bool
# piscina                       240000 non-null bool
# escuelascercanas              240000 non-null bool
# centroscomercialescercanos    240000 non-null bool
# precio                        240000 non-null float64
# dtypes: bool(5), datetime64[ns](1), float64(10), int64(1), object(6)
# memory usage: 34.1+ MB

# %%
df['escuelascercanas'].value_counts()
# Out:
# False    133406
# True     106594
# Name: escuelascercanas, dtype: int64

# %%
df['piscina'].value_counts()
# Out:
# 0.0    219028
# 1.0     20972
# Name: piscina, dtype: int64

# %%
df['centroscomercialescercanos'].value_counts()
# Out:
# 0.0    144832
# 1.0     95168
# Name: centroscomercialescercanos, dtype: int64

# %%
df['gimnasio'].value_counts()
# Out:
# 0.0    225006
# 1.0     14994
# Name: gimnasio, dtype: int64

# %%
df['usosmultiples'].value_counts()
# Out:
# 0.0    226778
# 1.0     13222
# Name: usosmultiples, dtype: int64

# %%
#NUMERICOS ENTEROS QUE ERAN INNECESARIAMENTE FLOAT
#------------------------------------------------#

#NUMERICOS QUE SOLO SON CERO O UNO
df['usosmultiples'] = df['usosmultiples'].astype('bool')
df['piscina'] = df['piscina'].astype('bool')
df['gimnasio'] = df['gimnasio'].astype('bool')
df['escuelascercanas'] = df['escuelascercanas'].astype('bool')
df['centroscomercialescercanos'] = df['centroscomercialescercanos'].astype('bool')


#FECHA DE PUBLICACION A DATETIME
df['fecha'] = pd.to_datetime(df['fecha'])


# A estos hay que limpiarles los inf y los NaN antes de convertir a int

#df['antiguedad'] = df.antiguedad.astype('int64')
#df['garages'] = df.garages.astype('int64')
#df['habitaciones'] = df.habitaciones.astype('int64')
#df['metrostotales'] = df.metrostotales.astype('int64')
#df['metroscubiertos'] = df.metroscubiertos.astype('int64')
#df['idzona'] = df.idzona.astype('int64')

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 240000 entries, 0 to 239999
# Data columns (total 23 columns):
# id                            240000 non-null int64
# titulo                        234613 non-null object
# descripcion                   238381 non-null object
# tipodepropiedad               239954 non-null object
# direccion                     186928 non-null object
# ciudad                        239628 non-null object
# provincia                     239845 non-null object
# antiguedad                    196445 non-null float64
# habitaciones                  217529 non-null float64
# garages                       202235 non-null float64
# banos                         213779 non-null float64
# metroscubiertos               222600 non-null float64
# metrostotales                 188533 non-null float64
# idzona                        211379 non-null float64
# lat                           116512 non-null float64
# lng                           116512 non-null float64
# fecha                         240000 non-null datetime64[ns]
# gimnasio                      240000 non-null bool
# usosmultiples                 240000 non-null bool
# piscina                       240000 non-null bool
# escuelascercanas              240000 non-null bool
# centroscomercialescercanos    240000 non-null bool
# precio                        240000 non-null float64
# dtypes: bool(5), datetime64[ns](1), float64(10), int64(1), object(6)
# memory usage: 34.1+ MB

# %%
# A estos hay que limpiarles los inf y los NaN antes de convertir a int

#df['antiguedad'] = df.antiguedad.astype('int64')
#df['garages'] = df.garages.astype('int64')
#df['habitaciones'] = df.habitaciones.astype('int64')
#df['metrostotales'] = df.metrostotales.astype('int64')
#df['metroscubiertos'] = df.metroscubiertos.astype('int64')
#df['idzona'] = df.idzona.astype('int64')

# %%
g = df["precio"].plot.hist(bins=30, color='lightgreen')
g.set_title("Histograma de precios [Precio de las propiedades]", fontsize=18)
g.set_xlabel("Precio",fontsize=18)
g.set_ylabel("Frecuencia", fontsize=18)
plt.xlim(0, 1.25e+7)
# Out:
# (0, 12500000.0)

# %%
df['precio'].plot(kind='box');

# %% [markdown]
# ## Precio promedio por tipo de propiedad

# %%
prop = df.dropna(subset=['tipodepropiedad'])
print(len(prop))
prop.head()
# Out:
# 239954
#        id                                             titulo  \
# 0  254099                                  depto. tipo a-402
# 1   53461                     condominio horizontal en venta
# 2  247984              casa en venta urbi 3 recamaras tonala
# 3  209067  casa sola en toluca zinacantepec con credito i...
# 4  185997                                     paseos del sol
#
#                                          descripcion     tipodepropiedad  \
# 0  depto. interior de 80.15m2, consta de sala com...         Apartamento
# 1  <p>entre sonora y guerrero, atr&aacute;s del h...  Casa en condominio
# 2  descripcion \nla mejor ubicacion residencial e...                Casa
# 3  casa en privada con caseta de vigilancia casas...                Casa
# 4  bonito departamento en excelentes condiciones ...         Apartamento
#
#                          direccion                  ciudad         provincia  \
# 0  Avenida Division del Norte 2005           Benito Juárez  Distrito Federal
# 1                       AV. MEXICO  La Magdalena Contreras  Distrito Federal
# 2                      Urbi Tonala                  Tonalá           Jalisco
# 3    IGNACIO MANUEL ALTAMIRANO 128            Zinacantepec    Edo. de México
# 4                  PASEOS DEL SOL                  Zapopan           Jalisco
#
#    antiguedad  habitaciones  garages  ...   idzona        lat        lng  \
# 0         NaN           2.0      1.0  ...  23533.0        NaN        NaN
# 1        10.0           3.0      2.0  ...  24514.0  19.310205 -99.227655
# 2         5.0           3.0      2.0  ...  48551.0        NaN        NaN
# 3         1.0           2.0      1.0  ...  53666.0  19.301890 -99.688015
# 4        10.0           2.0      1.0  ...  47835.0        NaN        NaN
#
#        fecha  gimnasio  usosmultiples piscina  escuelascercanas  \
# 0 2015-08-23     False          False   False             False
# 1 2013-06-28     False          False   False              True
# 2 2015-10-17     False          False   False             False
# 3 2012-03-09     False          False   False              True
# 4 2016-06-07     False          False   False             False
#
#    centroscomercialescercanos     precio
# 0                       False  2273000.0
# 1                        True  3600000.0
# 2                       False  1200000.0
# 3                        True   650000.0
# 4                       False  1150000.0
#
# [5 rows x 23 columns]

# %%
prop.groupby('tipodepropiedad').agg({'precio': 'mean'})\
    .sort_values('precio', ascending=True)\
    .plot(kind='bar', figsize=(15, 5), rot=70, title="Precio promedio por tipo de propiedad", color='orange');

# %% [markdown]
# En Mexico DF

# %%
prop_df = prop[prop['provincia'] == 'Distrito Federal']
prop_df.groupby('tipodepropiedad').agg({'precio': 'mean'})\
    .sort_values('precio', ascending=True)\
    .plot(kind='bar', figsize=(15, 5), rot=70, title="Precio promedio por tipo de propiedad En Mexico DF", color='lightblue');

# %%
labels = prop["tipodepropiedad"].tolist()
labels = list( dict.fromkeys(labels) )
labels.sort()
labels
# Out:
# ['Apartamento',
#  'Bodega comercial',
#  'Casa',
#  'Casa en condominio',
#  'Casa uso de suelo',
#  'Departamento Compartido',
#  'Duplex',
#  'Edificio',
#  'Garage',
#  'Hospedaje',
#  'Huerta',
#  'Inmuebles productivos urbanos',
#  'Local Comercial',
#  'Local en centro comercial',
#  'Lote',
#  'Nave industrial',
#  'Oficina comercial',
#  'Otros',
#  'Quinta Vacacional',
#  'Rancho',
#  'Terreno',
#  'Terreno comercial',
#  'Terreno industrial',
#  'Villa']

# %%
pres_df = prop_df.groupby('tipodepropiedad').agg({'precio': 'mean'})["precio"].tolist()
pres_df.insert(9, 0)
pres_df.insert(10, 0)
pres_all = prop.groupby('tipodepropiedad').agg({'precio': 'mean'})["precio"].tolist()

x = np.arange(len(labels)) # the label locations
width = 0.30  # the width of the bars

fig, ax = plt.subplots(figsize=(15, 7))
rects1 = ax.bar(x - width/2, pres_df, width, label='DF', color='lightblue')
rects2 = ax.bar(x + width/2, pres_all, width, label='All', color='orange')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Precio')
ax.set_title('Comparacion de precios por categoria entre todo Mexico y Mexico DF')
plt.xticks(x, labels, rotation='vertical')

ax.legend()

fig.tight_layout()

plt.show()

# %%
metros = df.dropna(subset=['metroscubiertos'])
metros = metros.dropna(subset=['metrostotales'])
metros.head()
# Out:
#        id                                             titulo  \
# 0  254099                                  depto. tipo a-402
# 1   53461                     condominio horizontal en venta
# 2  247984              casa en venta urbi 3 recamaras tonala
# 3  209067  casa sola en toluca zinacantepec con credito i...
# 4  185997                                     paseos del sol
#
#                                          descripcion     tipodepropiedad  \
# 0  depto. interior de 80.15m2, consta de sala com...         Apartamento
# 1  <p>entre sonora y guerrero, atr&aacute;s del h...  Casa en condominio
# 2  descripcion \nla mejor ubicacion residencial e...                Casa
# 3  casa en privada con caseta de vigilancia casas...                Casa
# 4  bonito departamento en excelentes condiciones ...         Apartamento
#
#                          direccion                  ciudad         provincia  \
# 0  Avenida Division del Norte 2005           Benito Juárez  Distrito Federal
# 1                       AV. MEXICO  La Magdalena Contreras  Distrito Federal
# 2                      Urbi Tonala                  Tonalá           Jalisco
# 3    IGNACIO MANUEL ALTAMIRANO 128            Zinacantepec    Edo. de México
# 4                  PASEOS DEL SOL                  Zapopan           Jalisco
#
#    antiguedad  habitaciones  garages  ...   idzona        lat        lng  \
# 0         NaN           2.0      1.0  ...  23533.0        NaN        NaN
# 1        10.0           3.0      2.0  ...  24514.0  19.310205 -99.227655
# 2         5.0           3.0      2.0  ...  48551.0        NaN        NaN
# 3         1.0           2.0      1.0  ...  53666.0  19.301890 -99.688015
# 4        10.0           2.0      1.0  ...  47835.0        NaN        NaN
#
#                  fecha  gimnasio  usosmultiples piscina  escuelascercanas  \
# 0  2015-08-23 00:00:00       0.0            0.0     0.0               0.0
# 1  2013-06-28 00:00:00       0.0            0.0     0.0               1.0
# 2  2015-10-17 00:00:00       0.0            0.0     0.0               0.0
# 3  2012-03-09 00:00:00       0.0            0.0     0.0               1.0
# 4  2016-06-07 00:00:00       0.0            0.0     0.0               0.0
#
#    centroscomercialescercanos     precio
# 0                         0.0  2273000.0
# 1                         1.0  3600000.0
# 2                         0.0  1200000.0
# 3                         1.0   650000.0
# 4                         0.0  1150000.0
#
# [5 rows x 23 columns]

# %%
x = metros['metroscubiertos'].tolist()
y = metros['metrostotales'].tolist()
z = metros['precio'].tolist()

# %%
##sns.cubehelix_palette(as_cmap=True)
cmap = sns.cubehelix_palette(as_cmap=True)

f, ax = plt.subplots(figsize=(15, 7))
points = ax.scatter(x, y, c=z, s=0.3, cmap=cmap)
f.colorbar(points)

# %%
#Vemos cuántos NaN hay por columna, sabiendo que el total es 240000
df.isnull().sum()
# Out:
# id                                 0
# titulo                          5387
# descripcion                     1619
# tipodepropiedad                   46
# direccion                      53072
# ciudad                           372
# provincia                        155
# antiguedad                     43555
# habitaciones                   22471
# garages                        37765
# banos                          26221
# metroscubiertos                17400
# metrostotales                  51467
# idzona                         28621
# lat                           123488
# lng                           123488
# fecha                              0
# gimnasio                           0
# usosmultiples                      0
# piscina                            0
# escuelascercanas                   0
# centroscomercialescercanos         0
# precio                             0
# dtype: int64

# %%
#Reemplazo los NaN por 0
df.loc[(df['lat']).isnull(),['lat']]=0
df.loc[(df['lng']).isnull(),['lng']]=0

# %%
df['lat'].isnull().sum()
# Out:
# 0

# %%
df['lng'].isnull().sum()
# Out:
# 0

# %%
df['lat'].value_counts()
# Out:
# 0.000000     123936
# 23.063781         8
# 23.054936         7
# 19.314000         6
# 19.392000         6
# 19.391000         6
# 19.617000         6
# 19.393000         6
# 19.358000         6
# 19.489000         6
# 23.053672         6
# 19.558000         6
# 19.457000         6
# 19.410000         6
# 32.454473         5
# 23.068835         5
# 19.300000         5
# 19.332000         5
# 19.503000         5
# 19.369000         5
# 19.485000         5
# 19.388000         5
# 19.344000         5
# 19.350000         5
# 19.387000         5
# 19.437000         5
# 19.397000         5
# 19.478000         5
# 19.444000         5
# 19.494000         5
#               ...
# 17.094446         1
# 20.997915         1
# 19.591669         1
# 19.417518         1
# 19.727337         1
# 19.476194         1
# 19.359454         1
# 19.287115         1
# 18.987497         1
# 19.495689         1
# 20.662757         1
# 19.492759         1
# 20.743466         1
# 21.160287         1
# 19.433077         1
# 19.359921         1
# 19.361805         1
# 20.642669         1
# 24.009796         1
# 32.485229         1
# 32.445024         1
# 20.658414         1
# 23.284804         1
# 22.645698         1
# 21.025559         1
# 25.675224         1
# 18.151347         1
# 18.779346         1
# 21.963000         1
# 19.505390         1
# Name: lat, Length: 112147, dtype: int64

# %%
df['lng'].value_counts()
# Out:
#  0.000000      123937
# -99.225000         12
# -99.218984          9
# -99.139000          8
# -99.213000          8
# -99.230000          8
# -99.143540          7
# -99.156000          7
# -99.125000          7
# -99.191000          7
# -99.227000          7
# -99.177446          7
# -99.234000          7
# -99.200000          7
# -99.144000          7
# -99.183676          7
# -99.163000          7
# -99.175000          6
# -99.171909          6
# -99.055727          6
# -99.153000          6
# -99.195000          6
# -99.202366          6
# -99.133163          6
# -99.170000          6
# -99.258000          6
# -99.226000          6
# -99.165000          6
# -99.211000          6
# -99.161000          6
#                 ...
# -100.976336         1
# -103.439241         1
# -103.464754         1
# -96.191890          1
# -99.303276          1
# -116.761322         1
# -106.117890         1
# -99.007759          1
# -98.941038          1
# -100.369562         1
# -102.311859         1
# -99.156190          1
# -99.136433          1
# -100.102952         1
# -100.428454         1
# -103.461922         1
# -99.285294          1
# -100.240945         1
# -98.213833          1
# -99.191613          1
# -99.185678          1
# -101.557630         1
# -103.387854         1
# -100.316000         1
# -102.308277         1
# -103.449196         1
# -100.443135         1
# -106.103384         1
# -99.168257          1
# -99.131383          1
# Name: lng, Length: 112326, dtype: int64

# %%
#Ahora cambio el tipo de dato de las columnas 'lat' y 'lng'
df['lat'] = df['lat'].astype(np.float32)
df['lng'] = df['lng'].astype(np.float32)

# %%
df['titulo'].value_counts()
# Out:
# casa en venta                                                                                           468
# departamento en venta                                                                                   289
# casa en venta en chihuahua                                                                              268
# casa en venta en querétaro                                                                              238
# departamento en venta en benito juárez                                                                  221
# departamento en venta en miguel hidalgo                                                                 177
# casa en venta en mérida                                                                                 167
# casa en venta                                                                                           132
# casa en venta en torreón                                                                                119
# casa en venta en monterrey                                                                              115
# casa en venta en mérida, yucatán                                                                        115
# casa en venta en puebla                                                                                 112
# casa en venta en juárez                                                                                 111
# casa en venta en tepic                                                                                  107
# casa en venta en juriquilla                                                                             106
# casa en venta en san andrés cholula                                                                     105
# casa en venta en tijuana                                                                                104
# venta de casa en aguascalientes                                                                          98
# terreno en venta                                                                                         97
# departamento                                                                                             89
# casa en condominio en venta en querétaro                                                                 86
# venta de departamento en benito juárez                                                                   84
# venta de casa en naucalpan                                                                               84
# departamento en venta en cuauhtémoc                                                                      84
# casa en venta en corregidora                                                                             83
# casa en venta en zapopan                                                                                 80
# casa en venta, monterrey, nuevo león                                                                     80
# departamento en venta en interlomas                                                                      80
# venta de casa en cuautitlan izcalli                                                                      79
# venta de casa en tlalnepantla                                                                            78
#                                                                                                        ...
# remate de departamento en la calle elvira vargas. cesion inmediata                                        1
# casa en venta estilo inglés en condado de sayavedra                                                       1
# benito juarez, viejo ejido santa ursula coapa  3mil                                                       1
# av. guadalupe                                                                                             1
# playa clave  en venta en carretera telchac km. 27, telchac pu, yucatan                                    1
# casa nueva galicia. sur .                                                                                 1
# del fresno bonita en coto 3 recamaras excelente estado ¡conozcala!                                        1
# lujosos departamentos nuevos frente al mar en venta, levant-boca, boca del rio veracruz                   1
# departamento en méxico nuevo                                                                              1
# venta oficinas en polanco                                                                                 1
# excelentes locales comerciales                                                                            1
# excelente departamento en condominio cuautitlan izcalli                                                   1
# se venden casas en cuautitlan                                                                             1
# bonita casa en el palomar con espectacular vista                                                          1
# departamento cerca del colegio salle y uvm                                                                1
# becal - sión bancaria                                                                                     1
# casa modelo barcelona en lomas residencial, oportunidad                                                   1
# casa en rancho tamboreo                                                                                   1
# departamento ubicadisimo en boca del rio amoblado o sin amoblar af227d                                    1
# bodega industrial (mb)                                                                                    1
# excelente local con buena ubicación                                                                       1
# local en venta plaza medica ii                                                                            1
# excelente departamento  en portales                                                                       1
# residencia en la encantada                                                                                1
# bonito depa en polanco. en rincón del bosque                                                              1
# local para restaurante bar cerca de unitec atizpan                                                        1
# departamento en venta  lincon, monterrey !!!**                                                            1
# estrene! casa en venta condesa de juriquilla                                                              1
# departamento ideal inversionistas                                                                         1
# remate - departamento residencial en venta en colonia portales norte, benito juárez, distrito federa      1
# Name: titulo, Length: 186191, dtype: int64

# %%
#Elimino los NaN
df.loc[(df['titulo']).isnull(), ['titulo']] = ''
df['titulo'] = df['titulo'].astype(str)

# %%
df['banos'].value_counts()
# Out:
# 2.0    87683
# 1.0    58173
# 3.0    49365
# 4.0    18558
# Name: banos, dtype: int64

# %%
#Lo paso a tipo category porque tenemos 4 valores distintos 
df.loc[(df['banos']).isnull(), ['banos']] = 0
df['banos'] = df['banos'].astype('category')

# %%
df['garages'].value_counts()
# Out:
# 2.0    94167
# 1.0    59464
# 0.0    26926
# 3.0    21678
# Name: garages, dtype: int64

# %%
#Lo paso a tipo category porque tenemos 4 valores distintos 
df.loc[(df['garages']).isnull(), ['garages']] = 0
df['garages'] = df['garages'].astype('category')

# %%
df['direccion'].value_counts()
# Out:
# -                                                               660
# .                                                               476
# 1                                                               212
# Calle                                                           194
# Norte de Mérida                                                 136
# x #x                                                            122
# 0                                                               113
# domicilio conocido                                              105
# Calle 18 No.344 x 11 y 13 Col. Camara de Comercio Norte          94
# calle                                                            94
# Juriquilla                                                       84
# El Refugio                                                       78
# x                                                                77
# Metepec                                                          77
# CENTRO                                                           75
# JURIQUILLA                                                       74
# ...                                                              70
# Sin nombre                                                       70
# EL REFUGIO                                                       68
# Bosque Real                                                      68
# Chihuahua, CHIH, México                                          67
# CALLE                                                            66
# S/N                                                              65
# Cumbres del Lago                                                 64
# Norte                                                            64
# --                                                               64
# S/D                                                              62
# Centro                                                           62
# cancun                                                           58
# Hidalgo                                                          55
#                                                                ...
# Avenida federalistas 909 casa14 Real del Bosque                   1
# Col Bosque Real                                                   1
# LOMA LINDA QRO-005                                                1
# Pico de Verapaz 507                                               1
# JARDIN DE LAS FLORES 251 -252                                     1
# RIO CANDELARIA 161                                                1
# Privada Badajo 5a. sección                                        1
# Salvador Diaz Miron esquina Circuito Interior                     1
# Ignacio Ramirez 1163                                              1
# palma y tamaulipas                                                1
# Infonavit norte                                                   1
# FG69                                                              1
# Av. Juan Palomar y Arias 930, Jardines Universidad, zapopan,      1
# Jose Manuel Othon 48                                              1
# Paseo de la Asunción No.101 La Joya Metepec Estado de México      1
# 16a. Av. Norte Poniente 898                                       1
# COLONIA FUERTE DE LORETO                                          1
# DEBH0921                                                          1
# calle 21 # 117-C entre 24 y 24-A itzimná                          1
# CALLE TOLSA                                                       1
# Playa Encantada 28                                                1
# Norte 32 145                                                      1
# Calle Torrecillas #203                                            1
# av. radial aquiles serdan #297 ed. B  dpt. #304                   1
# Av. Río Nilo #3360                                                1
# Sm 44 calle Eclipse mz 15 Cancun Q.Roo                            1
# Las Torres 10                                                     1
# Calle: Pima Bajo   Col: Carlos Zapata Vela  Del: Iztacalco        1
# SANTA LUCIA 255                                                   1
# SANTA ROSA INTERIOR 27                                            1
# Name: direccion, Length: 140269, dtype: int64

# %%
#Limpio las direcciones que no son calles

df.loc[(df['direccion']).isnull(), ['direccion']] = 'S/D'
df.loc[(df['direccion']) == 'S/N', ['direccion']] = 'S/D'
df.loc[(df['direccion']) == 'Sin nombre', ['direccion']] = 'S/D'
df.loc[(df['direccion']) == '0', ['direccion']] = 'S/D'
df.loc[(df['direccion']) == '--', ['direccion']] = 'S/D'
df.loc[(df['direccion']) == '...', ['direccion']] = 'S/D'
df.loc[(df['direccion']) == '-', ['direccion']] = 'S/D'
df.loc[(df['direccion']) == '.', ['direccion']] = 'S/D'
df.loc[(df['direccion']) == 'x #x', ['direccion']] = 'S/D'
df.loc[(df['direccion']) == 'x', ['direccion']] = 'S/D'
df.loc[(df['direccion']) == 'calle', ['direccion']] = 'S/D'
df.loc[(df['direccion']) == 'Calle', ['direccion']] = 'S/D'
df.loc[(df['direccion']) == '1', ['direccion']] = 'S/D'
df.loc[(df['direccion']) == 'X', ['direccion']] = 'S/D'

# %%
df['direccion'] = df['direccion'].astype('str')
